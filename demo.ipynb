# %%
from src.WordCloud import WordCloudFT

# %%
wc = WordCloudFT(None, path_to_litter='')
# Out:
# Retrieving folder contents
# Processing file 188akoDklsVa5rv7Ay-s-B6UsYg9ZKDNr synonyms_ft.model2
# Processing file 1u4R_6Aj5UMHTjV5nPVkyczieplntpJhB synonyms_ft.model2.syn1.npy
# Processing file 1Zz28dhZBILLvWU53cBasUdo5bg9dTGAm synonyms_ft.model2.wv.vectors_ngrams.npy
# Processing file 1Tim6p72F_pFi1ImUmi8Yq8nxcbg8kZ8e synonyms_ft.model2.wv.vectors_vocab.npy
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=188akoDklsVa5rv7Ay-s-B6UsYg9ZKDNr
# To: d:\PythonProjects\WordCloud\modelWordCloud\synonyms_ft.model2
# 100%|██████████| 83.5M/83.5M [00:08<00:00, 9.55MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1u4R_6Aj5UMHTjV5nPVkyczieplntpJhB
# From (redirected): https://drive.google.com/uc?id=1u4R_6Aj5UMHTjV5nPVkyczieplntpJhB&confirm=t&uuid=c78b6e77-505b-4baf-9684-78333731c1a3
# To: d:\PythonProjects\WordCloud\modelWordCloud\synonyms_ft.model2.syn1.npy
# 100%|██████████| 270M/270M [00:27<00:00, 10.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Zz28dhZBILLvWU53cBasUdo5bg9dTGAm
# From (redirected): https://drive.google.com/uc?id=1Zz28dhZBILLvWU53cBasUdo5bg9dTGAm&confirm=t&uuid=604b37ea-f1bd-4fc5-a083-df68e7732a58
# To: d:\PythonProjects\WordCloud\modelWordCloud\synonyms_ft.model2.wv.vectors_ngrams.npy
# 100%|██████████| 1.20G/1.20G [02:11<00:00, 9.15MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Tim6p72F_pFi1ImUmi8Yq8nxcbg8kZ8e
# From (redirected): https://drive.google.com/uc?id=1Tim6p72F_pFi1ImUmi8Yq8nxcbg8kZ8e&confirm=t&uuid=e56441f2-d1ef-42c5-a818-7e8e82483d73
# To: d:\PythonProjects\WordCloud\modelWordCloud\synonyms_ft.model2.wv.vectors_vocab.npy
# 100%|██████████| 270M/270M [00:29<00:00, 9.05MB/s]
# Download completed

# %%
wc.set_word_list('./materials/examples.csv')

# %%
wc.fit()

# %%
wc.cloud_barchart()

# %%
wc.cloud_cloud()
